# %% [markdown]
# <a href="https://colab.research.google.com/github/Schiavi13/analisis-impacto-covid19-en-inversion-ecoeficiencia-empresarial-2019-2023/blob/luis_001/src/merge_datasets_ambiental_general_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Unificación de datasets ambiental y general del año 2023

# %%
# importar librerias
import pandas as pd
print("Carga de librerías exitosa")
# Out:
# Carga de librerías exitosa

# %%
# Carga datasets ambiental y general
df_ambiental_2023 = pd.read_csv("/content/drive/MyDrive/Bootcamp Análisis de Datos/Grupo Q/data/procesados/ambiental/2023_eas_ambiental.csv")
df_ambiental_2023.head()
# Out:
#    id_empresa  periodo id_sector                sector_desc  gastos_totales  \
# 0       10429     2023        H1  auxiliares del transporte       141276673
# 1       10213     2023        H1  auxiliares del transporte       141276673
# 2       13851     2023        H1  auxiliares del transporte       141276673
# 3       10439     2023        H1  auxiliares del transporte        34597790
# 4       13853     2023        H1  auxiliares del transporte        34597790
#
#    gasto_gestion_amb  contrata_personal_amb  realiza_inv_red_emision_aire  \
# 0             331267                      1                             1
# 1             331267                      1                             0
# 2             331267                      1                             0
# 3             180809                      1                             0
# 4             180809                      0                             0
#
#    realiza_inv_ahorro_agua  realiza_inv_inst_med_agua  ...  \
# ...

# %%
df_general_2023 = pd.read_csv("/content/drive/MyDrive/Bootcamp Análisis de Datos/Grupo Q/data/procesados/general/2023_eas_general.csv")
df_general_2023.head()
# Out:
#    id_empresa  anio_inicio  periodo id_sector_general total_ingresos  \
# 0       10001         1992     2023                I1        3456999
# 1       10002         1994     2023                I1        7226625
# 2       10003         2015     2023                I1       13894282
# 3       10004         2017     2023                I1       13249524
# 4       10005         1957     2023                I2       46060505
#
#    personal_remunerado  gasto_remuneracion_personal  gasto_personal_total  \
# 0                 39.0                       981704                981704
# 1                 36.0                      1065968               1113323
# 2                 77.0                      2394824               2422620
# 3                139.0                      3211998               3234865
# 4                119.0                      4492465               5184918
#
#    personal_mujeres  personal_hombres  personal_ocupado imp_ind_com imp_otros  \
# ...

# %% [markdown]
# Se unifican los datasets mediante un inner join con el id de la empresa

# %%
# Merge de los dos datasets por campo id_empresa
df_servicios_unificado_2023 = pd.merge(df_ambiental_2023, df_general_2023, on="id_empresa", how="inner")
df_servicios_unificado_2023.head()
# Out:
#    id_empresa  periodo_x id_sector                sector_desc  gastos_totales  \
# 0       10429       2023        H1  auxiliares del transporte       141276673
# 1       10213       2023        H1  auxiliares del transporte       141276673
# 2       13851       2023        H1  auxiliares del transporte       141276673
# 3       10439       2023        H1  auxiliares del transporte        34597790
# 4       13853       2023        H1  auxiliares del transporte        34597790
#
#    gasto_gestion_amb  contrata_personal_amb  realiza_inv_red_emision_aire  \
# 0             331267                      1                             1
# 1             331267                      1                             0
# 2             331267                      1                             0
# 3             180809                      1                             0
# 4             180809                      0                             0
#
# ...

# %%
# inspecciona el dataframe unificado
df_servicios_unificado_2023.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6211 entries, 0 to 6210
# Data columns (total 39 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   id_empresa                       6211 non-null   int64
#  1   periodo_x                        6211 non-null   int64
#  2   id_sector                        6211 non-null   object
#  3   sector_desc                      6211 non-null   object
#  4   gastos_totales                   6211 non-null   int64
#  5   gasto_gestion_amb                6211 non-null   int64
#  6   contrata_personal_amb            6211 non-null   int64
#  7   realiza_inv_red_emision_aire     6211 non-null   int64
#  8   realiza_inv_ahorro_agua          6211 non-null   int64
#  9   realiza_inv_inst_med_agua        6211 non-null   int64
#  10  realiza_inv_disp_desechos        6211 non-null   int64
#  11  realiza_inv_protec_suelo         6211 non-null   int64
# ...

# %% [markdown]
# Existen columnas con el mismo nombre en ambos datasets, por lo tanto pandas les modifica el nombre, a continuación se deja una sola con el nombre original.

# %%
# Elimina columna periodo repetida
df_servicios_unificado_2023.drop(columns=["periodo_y"], inplace=True)
df_servicios_unificado_2023.rename(columns={"periodo_x":"periodo"}, inplace=True)
print(df_servicios_unificado_2023.columns)
# Out:
# Index(['id_empresa', 'periodo', 'id_sector', 'sector_desc', 'gastos_totales',
#        'gasto_gestion_amb', 'contrata_personal_amb',
#        'realiza_inv_red_emision_aire', 'realiza_inv_ahorro_agua',
#        'realiza_inv_inst_med_agua', 'realiza_inv_disp_desechos',
#        'realiza_inv_protec_suelo', 'realiza_inv_evita_ruido_vibra',
#        'realiza_inv_energia_limp', 'realiza_otras_inv_amb',
#        'realiza_gasto_red_emision_aire', 'realiza_gasto_ahorro_agua',
#        'realiza_gasto_inst_med_agua', 'realiza_gasto_disp_desechos',
#        'realiza_gasto_protec_suelo', 'realiza_gasto_evita_ruido_vibra',
#        'realiza_gasto_terceros_amb', 'realiza_gasto_energia_limp',
#        'realiza_otros_gastos_amb', 'anio_inicio', 'id_sector_general',
#        'total_ingresos', 'personal_remunerado', 'gasto_remuneracion_personal',
#        'gasto_personal_total', 'personal_mujeres', 'personal_hombres',
#        'personal_ocupado', 'imp_ind_com', 'imp_otros',
# ...

# %% [markdown]
# ## Verificación de consistencia de id_empresa e id_sector
# Se comparan los id_sector e id_sector_general, y si son inconsistentes se busca la razón para realizar ajustes o eliminar registros.

# %%
# Extrae id_sector diferentes
condicion_diferente_Sector = df_servicios_unificado_2023['id_sector'] != df_servicios_unificado_2023['id_sector_general']
df_servicios_unificado_2023.loc[condicion_diferente_Sector,
                                ['id_empresa',
                                 'id_sector',
                                 'total_ingresos',
                                 'id_sector_general']]
# Out:
#       id_empresa id_sector total_ingresos id_sector_general
# 54         21052        I2       31999563                 Q
# 108        20927        J4       12815089                N3
# 110        20857        J4      136624633                 Q
# 124        20925        J4       14644693                H1
# 127        18208        LN       94668755               LN1
# ...          ...       ...            ...               ...
# 5890       20991         Q       15495119                N4
# 5901       20898         R      210285510                N3
# 5913       20964         R        5897285                M1
# 5914       20985         R       21623667                N3
# 5915       20987         R       22219164                N3
#
# [493 rows x 4 columns]

# %% [markdown]
# Se evidencia que el sector "LN1" en id_sector_general tiene un número extra, se puede ajustar a "LN" para que coincida sin modificar los datos. Por otro lado, existen id_sector que no tienen relación, se aislan y se eliminan del análisis estos registros.

# %%
# Corrige id_sector_general LN1 a LN
df_servicios_unificado_2023['id_sector_general'] = df_servicios_unificado_2023['id_sector_general'].mask(df_servicios_unificado_2023['id_sector_general']=='LN1', 'LN')
condicion_diferente_Sector = df_servicios_unificado_2023['id_sector'] != df_servicios_unificado_2023['id_sector_general']
df_servicios_unificado_2023.loc[condicion_diferente_Sector,
                                ['id_empresa',
                                 'id_sector',
                                 'total_ingresos',
                                 'id_sector_general']]
# Out:
#       id_empresa id_sector total_ingresos id_sector_general
# 54         21052        I2       31999563                 Q
# 108        20927        J4       12815089                N3
# 110        20857        J4      136624633                 Q
# 124        20925        J4       14644693                H1
# 137        20899        LN       84868861                 R
# ...          ...       ...            ...               ...
# 5890       20991         Q       15495119                N4
# 5901       20898         R      210285510                N3
# 5913       20964         R        5897285                M1
# 5914       20985         R       21623667                N3
# 5915       20987         R       22219164                N3
#
# [175 rows x 4 columns]

# %%
# Elimina registros con incongruencias en id_sector e id_sector_general
df_servicios_unificado_2023 = df_servicios_unificado_2023[df_servicios_unificado_2023['id_sector'] == df_servicios_unificado_2023['id_sector_general']]
df_servicios_unificado_2023.shape
# Out:
# (6036, 38)

# %%
# Verifica id_sector
condicion_diferente_Sector = df_servicios_unificado_2023['id_sector'] != df_servicios_unificado_2023['id_sector_general']
df_servicios_unificado_2023.loc[condicion_diferente_Sector,
                                ['id_empresa',
                                 'id_sector',
                                 'total_ingresos',
                                 'id_sector_general']]
# Out:
# Empty DataFrame
# Columns: [id_empresa, id_sector, total_ingresos, id_sector_general]
# Index: []

# %% [markdown]
# Se eliminaron satisfactoriamente los registros con id_sector inconsistentes

# %% [markdown]
# ## Exporta datos
# Exporta el dataframe unificado a la carpeta de datasets unificados

# %%
# Exporta el dataframe como csv
df_servicios_unificado_2023.to_csv("/content/drive/MyDrive/Bootcamp Análisis de Datos/Grupo Q/data/procesados/unificados/2023_eas_unificado.csv", index=False)
